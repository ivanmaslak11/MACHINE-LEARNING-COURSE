# %% [markdown]
# # Домашнее задание №1. Pandas. numpy. Обработка данных
#
# ## Ф.И.О: Маслак Иван Александрович
#
# Домашнее задание состоит из **2**-х частей:
# - **Первая часть** посвящена эффективной реализации функций подсчета расстояния с использованием библиотеки _numpy_.
# - **Вторая часть** предполагает заполнение предложенного блокнота.
#
# ### Часть 0.
# - Вписать Ваши ФИО в предложенное поле.
#
#
# ### Часть 1. (5 баллов)
# - реализуйте функции для вычисления расстояния из модуля ``tasks`` с использованием _numpy_
# - запрещается использовать циклы и конструкцию list comprehension
# - запрещается использовать сторонние библиотеки (за исключением _numpy_)
# - для проверки можете использовать приложенные unit-тесты
#    - чтобы запустить их в консоли выполните:
#       ``$ python -m unittest``
#
# ### Часть 2. (15 баллов)
# - заполните предложенный блокнот кодом и ответами на вопросы, где это требуется
#
# ----------------------------------------
#
# **На проверку требуется отправить zip архив, который будет содержать следующие файлы:**
#  - модуль ``tasks.py`` с реализованными функциями
#  - заполненный блокнот в формате ``.ipynb``
#  - заполненный блокнот в формате ``.html`` **(в jupyter: File -> Save and Export Notebook As -> HTML -> ...)**
#  - файл ``answer.csv``, который получится в результате работы над блокнотом

# %% [markdown]
# ### Часть 2. (15 points)
#
# ----------------------------
#
# #### __1__. (2 points)
#
# __1.1__. Импортируйте все необходимые библиотеки.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)
pd.set_option('display.precision', 3)

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# __1.2__. Загрузите файл `train.csv` и сохраните его в переменную `df`. Выведите первые 10 строчек таблицы.

# %%
df = pd.read_csv("train.csv")
df.head(10)
# Out:
#        PERIOD  cl_id   MCC channel_type  currency        TRDATETIME   amount  \
# 0  01/10/2017      0  5200          NaN       810  21OCT17:00:00:00   5023.0
# 1  01/10/2017      0  6011          NaN       810  12OCT17:12:24:07  20000.0
# 2  01/12/2017      0  5921          NaN       810  05DEC17:00:00:00    767.0
# 3  01/10/2017      0  5411          NaN       810  21OCT17:00:00:00   2031.0
# 4  01/10/2017      0  6012          NaN       810  24OCT17:13:14:24  36562.0
# 5  01/10/2017      1  5814          NaN       810  16OCT17:00:00:00    380.0
# 6  01/10/2017      1  5814          NaN       810  10OCT17:00:00:00    378.0
# 7  01/10/2017      1  5814          NaN       810  16OCT17:00:00:00    199.0
# 8  01/10/2017      1  5814          NaN       810  11OCT17:00:00:00    400.0
# 9  01/07/2017      1  5411          NaN       810  26JUL17:00:00:00    598.0
#
#   trx_category  target_flag  target_sum
# 0          POS            0         0.0
# 1      DEPOSIT            0         0.0
# 2          POS            0         0.0
# 3          POS            0         0.0
# 4      C2C_OUT            0         0.0
# 5          POS            0         0.0
# 6          POS            0         0.0
# 7          POS            0         0.0
# 8          POS            0         0.0
# 9          POS            0         0.0

# %%
np.random.seed(9564)
index = np.random.choice(len(df), replace=False, size=1000)

# %% [markdown]
# __1.3__.1. Выведите размер получившейся таблицы.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

table_size = df.shape[0]
print(f"Размер таблицы: {table_size}")
# Out:
# Размер таблицы: 490513

# %% [markdown]
# __1.3__.2. Выведите статистики (среднее, дисперсию, кванти́ли, количество значений и т.п.) по каждому из столбцов. Воспользуйтесь специальным методом у `df`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################
df.describe()
# Out:
#             cl_id         MCC    currency     amount  target_flag  target_sum
# count  490513.000  490513.000  490513.000  4.905e+05   490513.000   4.905e+05
# mean     4802.127    5699.784     810.602  5.724e+03        0.653   1.627e+05
# std      2986.493     662.933      38.223  7.704e+04        0.476   1.474e+06
# min         0.000     742.000      32.000  4.000e-02        0.000   0.000e+00
# 25%      2193.000    5411.000     810.000  2.240e+02        0.000   0.000e+00
# 50%      4576.000    5661.000     810.000  6.240e+02        1.000   2.491e+04
# 75%      7390.000    5941.000     810.000  2.176e+03        1.000   1.516e+05
# max     10215.000    9405.000     986.000  3.584e+07        1.000   4.607e+07

# %% [markdown]
# Описание столбцов:
# * PERIOD – месяц транзакции;
# * cl_id – id клиента;
# * MCC – код категории продавца;
# * channel_type – канал привлечения клиента;
# * currency – валюта;
# * TRDATETIME – дата/время транзакции;
# * amount – сумма транзакции;
# * trx_category – вид транзакции.
#
# Виды транзакций:
# * POS – оплата через POS терминал;
# * C2C_IN – перевод на карту (входящий платёж);
# * C2C_OUT – перевод на карту (исходящий платёж);
# * DEPOSIT – пополнение карты в банкомате;
# * WD_ATM_PARTNER – снятие наличных в банкоматах партнерах банка *UNKNOWN*;
# * WD_ATM_ROS – снятие наличных в банкоматах банка *UNKNOWN*;
# * WD_ATM_OTHER – снятия в других банкоматах;
# * BACK_TRX – возврат средств при возврате покупки;
# * CAT – операции в банкоматах;
# * CASH_ADV – снятие карты в кассе банка.

# %% [markdown]
# __1.4__. Какие столбцы имеют пропущенные значения? Сколько пропущенных значений?

# %%
missed_values = df.isnull().sum()

print("Пропущенные значения:")
print(missed_values, '\n')
print(f"Всего пропущено: {missed_values.sum()}")
# Out:
# Пропущенные значения:
# PERIOD             0
# cl_id              0
# MCC                0
# channel_type    2910
# currency           0
# TRDATETIME         0
# amount             0
# trx_category       0
# target_flag        0
# target_sum         0
# dtype: int64
#
# Всего пропущено: 2910

# %% [markdown]
# __1.5__. Какие уникальные значения существуют у столбца `currency`?

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################
print(f"Уникальные значения currency: {df['currency'].unique()}")
# Out:
# Уникальные значения currency: [810 978 504 704 981 985 840 949  51 826 214 764 203 702 360 756 933 975
#   36 191 784 980 124 398 376 944 352 417 156 752 392 484 634 188 643 348
#  356 458 986 498 578 208 344  32 410 788 480 604 941 144 946 710 690  44
#  170 901 608 554 462]

# %% [markdown]
# __1.6__. Заполните пропуски в столбце `channel_type` значением `type0`. Результат должен сохраниться в переменной `df`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################
df['channel_type'] = df['channel_type'].fillna('type0')

# %%
df.head()
# Out:
#        PERIOD  cl_id   MCC channel_type  currency        TRDATETIME   amount  \
# 0  01/10/2017      0  5200        type0       810  21OCT17:00:00:00   5023.0
# 1  01/10/2017      0  6011        type0       810  12OCT17:12:24:07  20000.0
# 2  01/12/2017      0  5921        type0       810  05DEC17:00:00:00    767.0
# 3  01/10/2017      0  5411        type0       810  21OCT17:00:00:00   2031.0
# 4  01/10/2017      0  6012        type0       810  24OCT17:13:14:24  36562.0
#
#   trx_category  target_flag  target_sum
# 0          POS            0         0.0
# 1      DEPOSIT            0         0.0
# 2          POS            0         0.0
# 3          POS            0         0.0
# 4      C2C_OUT            0         0.0

# %% [markdown]
# __1.7__. Посчитайте, сколько записей приходится на каждое уникальное значение столбца `channel_type`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

value_counts = df['channel_type'].value_counts()
value_counts = pd.DataFrame({
    'channel_type': value_counts.index,
    'количество значений': value_counts.values
})
print(value_counts)
# Out:
#   channel_type  количество значений
# 0        type1               299247
# 1        type2               175013
# 2        type5                 5587
# 3        type4                 4476
# 4        type3                 3280

# %% [markdown]
# __1.8__. Найдите топ-3 `MCC` категорий с наибольшим объемом трат (поле `amount`).

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

most_spended = df.groupby('MCC')['amount'].sum().sort_values(ascending=False)
print(f"MCC с наибольшим обЪёмом трат:\n {most_spended.head(3)}")
# Out:
# MCC с наибольшим обЪёмом трат:
#  MCC
# 6011    1.494e+09
# 6012    1.849e+08
# 5411    1.347e+08
# Name: amount, dtype: float64

# %% [markdown]
# ----------------------------------
#
# #### __2__. (1 point)
#
# __2.1__. Сделайте значения в столбцах `channel_type` и `trx_category` категориальными.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df[['channel_type', 'trx_category']] = df[['channel_type', 'trx_category']].astype('category')

# %% [markdown]
# __2.2__. Сделайте столбец `trx_category_mul`, который показывает увеличение (значение в столбце равно +1) и уменьшение средств (значение в столбце равно -1) на счете клиента банка. Операции, которые увеличивают количество средств на счете:
# `C2C_IN`, `DEPOSIT`, `BACK_TRX`. Считайте, что остальные операции уменьшают количество средств на счете.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df['trx_category_mul'] = np.where(df['trx_category'].isin(['C2C_IN', 'DEPOSIT', 'BACK_TRX']), 1, -1)

# %%
df.loc[:, ['trx_category_mul', 'trx_category']].head()
# Out:
#    trx_category_mul trx_category
# 0                -1          POS
# 1                 1      DEPOSIT
# 2                -1          POS
# 3                -1          POS
# 4                -1      C2C_OUT

# %% [markdown]
# -------------------------------------------------
#
# #### __3__. (1 point)
#
# __3.0__. Приведем столбец `TRDATETIME` к типу даты.

# %%
from datetime import datetime

df["TRDATETIME"] = pd.to_datetime(df["TRDATETIME"], format='%d%b%y:%H:%M:%S')

# %% [markdown]
# Извлеките из столбца `TRDATETIME` следующие признаки:
# * `mday` – день (с начала месяца);
# * `ymonth` – месяц;
# * `year` – год;
# * `wday` – день недели;
# * `is_weekend` – является ли день выходным днем.
#
# Извлеченные признаки запишите в таблицу `df_time`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

datetime = df['TRDATETIME']

df_time = pd.DataFrame({
    'mday' : datetime.dt.day,
    'ymonth' : datetime.dt.month,
    'year' : datetime.dt.year,
    'wday' : datetime.dt.dayofweek,
    'is_weekend' : datetime.dt.dayofweek >= 5
})

# %%
df_time.head()
# Out:
#    mday  ymonth  year  wday  is_weekend
# 0    21      10  2017     5        True
# 1    12      10  2017     3       False
# 2     5      12  2017     1       False
# 3    21      10  2017     5        True
# 4    24      10  2017     1       False

# %% [markdown]
# __3.1__. Объедините таблицы `df` и `df_time` и сохраните результат в `df`. При объединении используйте аргумент `sort=False`, если он имеется.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################
df = pd.concat([df, df_time], axis=1, sort=False)

# %%
df.head()
# Out:
#        PERIOD  cl_id   MCC channel_type  currency          TRDATETIME  \
# 0  01/10/2017      0  5200          NaN       810 2017-10-21 00:00:00
# 1  01/10/2017      0  6011          NaN       810 2017-10-12 12:24:07
# 2  01/12/2017      0  5921          NaN       810 2017-12-05 00:00:00
# 3  01/10/2017      0  5411          NaN       810 2017-10-21 00:00:00
# 4  01/10/2017      0  6012          NaN       810 2017-10-24 13:14:24
#
#     amount trx_category  target_flag  target_sum  trx_category_mul  mday  \
# 0   5023.0          POS            0         0.0                -1    21
# 1  20000.0      DEPOSIT            0         0.0                 1    12
# 2    767.0          POS            0         0.0                -1     5
# 3   2031.0          POS            0         0.0                -1    21
# 4  36562.0      C2C_OUT            0         0.0                -1    24
#
#    ymonth  year  wday  is_weekend
# 0      10  2017     5        True
# 1      10  2017     3       False
# 2      12  2017     1       False
# 3      10  2017     5        True
# 4      10  2017     1       False

# %% [markdown]
# --------------------------
#
# #### __4__. (1 point)
#
# __4.1__. Загрузите таблицу `mcc_codes_ru.csv` и сохраните в переменную `df_mcc`. Выведите первые 5 строчек таблицы.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df_mcc = pd.read_csv('mcc_codes_ru.csv')
df_mcc.head(5)
# Out:
#     MCC                                           Название  \
# 0   742                                Ветеринарные услуги
# 1   763                   Сельскохозяйственные кооперативы
# 2   780          Услуги садоводства и ландшафтного дизайна
# 3  1520  Генеральные подрядчики – жилое и коммерческое ...
# 4  1711  Генеральные подрядчики по вентиляции, теплосна...
#
#                Группа Обновлено
# 0  Контрактные услуги  31.01.18
# 1  Контрактные услуги  31.01.18
# 2  Контрактные услуги  31.01.18
# 3  Контрактные услуги  31.01.18
# 4  Контрактные услуги  31.01.18

# %% [markdown]
# __4.2__. Переименуйте столбцы в `df_mcc` следующим образом:
# * `MCC` -> `MCC`;
# * `Название` -> `mcc_name`;
# * `Группа` -> `mcc_group`;
# * `Обновлено` -> `updated`.
#
# Результат сохраните в `df_mcc`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df_mcc = df_mcc.rename(columns={
    'MCC' : 'MCC',
    'Название' : 'mcc_name',
    'Группа' : 'mcc_group',
    'Обновлено' : 'updated'
})

# %%
df_mcc.head()
# Out:
#     MCC                                           mcc_name  \
# 0   742                                Ветеринарные услуги
# 1   763                   Сельскохозяйственные кооперативы
# 2   780          Услуги садоводства и ландшафтного дизайна
# 3  1520  Генеральные подрядчики – жилое и коммерческое ...
# 4  1711  Генеральные подрядчики по вентиляции, теплосна...
#
#             mcc_group   updated
# 0  Контрактные услуги  31.01.18
# 1  Контрактные услуги  31.01.18
# 2  Контрактные услуги  31.01.18
# 3  Контрактные услуги  31.01.18
# 4  Контрактные услуги  31.01.18

# %% [markdown]
# __4.3__. Удалите столбец `updated` из `df_mcc`, результат сохраните в `df_mcc`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df_mcc = df_mcc.drop(['updated'], axis=1)

# %%
df_mcc.head()
# Out:
#     MCC                                           mcc_name           mcc_group
# 0   742                                Ветеринарные услуги  Контрактные услуги
# 1   763                   Сельскохозяйственные кооперативы  Контрактные услуги
# 2   780          Услуги садоводства и ландшафтного дизайна  Контрактные услуги
# 3  1520  Генеральные подрядчики – жилое и коммерческое ...  Контрактные услуги
# 4  1711  Генеральные подрядчики по вентиляции, теплосна...  Контрактные услуги

# %% [markdown]
# __4.4__. Закодируйте столбец `mcc_group` с помощью label-кодирования.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df_mcc['mcc_group'] = encoder.fit_transform(df_mcc['mcc_group'])

# %%
df_mcc.head()
# Out:
#     MCC                                           mcc_name  mcc_group
# 0   742                                Ветеринарные услуги          6
# 1   763                   Сельскохозяйственные кооперативы          6
# 2   780          Услуги садоводства и ландшафтного дизайна          6
# 3  1520  Генеральные подрядчики – жилое и коммерческое ...          6
# 4  1711  Генеральные подрядчики по вентиляции, теплосна...          6

# %% [markdown]
# --------------------------------------
# #### __5__. (2 points)
#
# __5.1__. Присоедините к таблице `df` столбец `mcc_group`. Результат сохраните в `df`.
#
# **Какой тип JOIN-а подойдет лучше всего для этой задачи?**
#
# $\textcolor{red}{Ваш \ ответ:}$
#
# Лучше использовать left join (если df слева), так как в df_mcc могут быть не все коды категории продавцов из df, поэтому иначе данные из df могут быть утеряны

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df = pd.merge(df, df_mcc[['MCC', 'mcc_group']], on='MCC', how='left')

# %%
df.iloc[index].head()
# Out:
#             PERIOD  cl_id   MCC channel_type  currency TRDATETIME  amount  \
# 51305   01/06/2017    913  7230        type2       810 2017-06-14  2100.0
# 226863  01/07/2017   4183  5499        type1       810 2017-07-20   140.0
# 124479  01/11/2017   2253  5735        type2       810 2017-11-28   397.0
# 11132   01/08/2017    225  5411        type4       810 2017-08-07    44.9
# 473017  01/03/2017   9869  5812        type1       810 2017-03-30   350.0
#
#        trx_category  target_flag  target_sum  trx_category_mul  mday  ymonth  \
# 51305           POS            1   449004.29                -1    14       6
# 226863          POS            1   132726.55                -1    20       7
# 124479          POS            1       59.00                -1    28      11
# 11132           POS            1   466235.45                -1     7       8
# 473017          POS            0        0.00                -1    30       3
#
#         year  wday  is_weekend  mcc_group
# 51305   2017     2       False        7.0
# 226863  2017     3       False       17.0
# 124479  2017     1       False       15.0
# 11132   2017     0       False       17.0
# 473017  2017     3       False       15.0

# %% [markdown]
# ----------------------------------------
#
# ---
#
#
#
# #### __6__. (2 points)
# Выведите сумму, среднее и среднеквадратичное отклонение трат `amount` по каждой из категорий `trx_category` в рамках канала привлечения `channel_type`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

amount_stats = df.groupby(['channel_type', 'trx_category'])['amount'].agg([
    ('total_amount', 'sum'),
    ('mean', 'mean'),
    ('std', 'std')
]).reset_index()

amount_stats
# Out:
# /tmp/ipython-input-3913415129.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   amount_stats = df.groupby(['channel_type', 'trx_category'])['amount'].agg([
#    channel_type    trx_category  total_amount       mean         std
# 0         type1        BACK_TRX     2.055e+07  10979.486   55181.355
# 1         type1          C2C_IN     7.037e+07  13497.176   21455.762
# 2         type1         C2C_OUT     4.609e+07  16562.824   25755.712
# 3         type1        CASH_ADV     6.548e+05  25185.410   59272.348
# 4         type1             CAT     7.320e+06  16087.923   74133.156
# 5         type1         DEPOSIT     3.691e+08  21132.086   27362.956
# 6         type1             POS     6.323e+08   2472.164   70228.802
# 7         type1    WD_ATM_OTHER     3.840e+07  19145.017  177771.182
# 8         type1  WD_ATM_PARTNER     2.264e+08  47388.371   71325.839
# 9         type1      WD_ATM_ROS     3.837e+08  43278.339   55730.322
# 10        type2        BACK_TRX     3.422e+06   4700.521   12835.219
# 11        type2          C2C_IN     2.698e+07  14020.438   25895.815
# 12        type2         C2C_OUT     3.938e+07  15804.485   25665.438
# 13        type2        CASH_ADV     2.580e+05  32250.535   52204.208
# 14        type2             CAT     1.045e+07  16335.570   81574.126
# 15        type2         DEPOSIT     8.448e+07  30597.081   38968.512
# 16        type2             POS     3.464e+08   2357.908   98286.422
# 17        type2    WD_ATM_OTHER     3.421e+07   6909.320   32450.823
# 18        type2  WD_ATM_PARTNER     9.920e+07  20572.605   33867.718
# 19        type2      WD_ATM_ROS     2.699e+08  27632.246   43508.296
# 20        type3        BACK_TRX     3.222e+05  20139.201   35475.888
# 21        type3          C2C_IN     8.701e+04  10876.250   12332.637
# 22        type3         C2C_OUT     3.543e+04   5061.857    7569.332
# 23        type3        CASH_ADV     0.000e+00        NaN         NaN
# 24        type3             CAT     2.408e+06  63373.589  122651.324
# 25        type3         DEPOSIT     4.344e+06  23227.273   23103.532
# 26        type3             POS     7.837e+06   2755.509   10612.661
# 27        type3    WD_ATM_OTHER     2.460e+05   9840.080   19904.776
# 28        type3  WD_ATM_PARTNER     2.386e+06  28401.190   36133.539
# 29        type3      WD_ATM_ROS     2.274e+06  32023.944   44980.924
# 30        type4        BACK_TRX     2.259e+05   7531.287   28910.156
# 31        type4          C2C_IN     8.869e+05  15291.915   12320.494
# 32        type4         C2C_OUT     1.846e+06  20977.273   26067.515
# 33        type4        CASH_ADV     0.000e+00        NaN         NaN
# 34        type4             CAT     6.288e+04  12575.312   17346.537
# 35        type4         DEPOSIT     1.190e+07  39282.607   42093.366
# 36        type4             POS     1.169e+07   3138.924   23228.570
# 37        type4    WD_ATM_OTHER     1.829e+05   4572.299    4388.775
# 38        type4  WD_ATM_PARTNER     3.161e+06  38085.542   56640.958
# 39        type4      WD_ATM_ROS     7.700e+06  53475.694   66417.188
# 40        type5        BACK_TRX     6.224e+04   1682.229    2331.338
# 41        type5          C2C_IN     6.334e+05  10556.333   11777.934
# 42        type5         C2C_OUT     5.111e+05  13812.508   20574.017
# 43        type5        CASH_ADV     0.000e+00        NaN         NaN
# 44        type5             CAT     2.273e+06  45459.432   30754.892
# 45        type5         DEPOSIT     1.036e+07  28865.955   33653.585
# 46        type5             POS     1.036e+07   2218.382   20558.593
# 47        type5    WD_ATM_OTHER     6.203e+05   6461.146   16581.908
# 48        type5  WD_ATM_PARTNER     1.367e+06   9300.000   19181.198
# 49        type5      WD_ATM_ROS     2.724e+06  20636.364   32177.241

# %% [markdown]
# ---------------------------------
#
# #### __7__. (2 points)
#
# Выведите топ-5 клиентов, с наибольшим оборотом по `С2С` транзакциям. Под оборотом подразумевается полный объем полученных и переведенных средств без учета знака (т.е. не имеет значения получал ли клиент средства на свой счет, или переводил их на другой счет).

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################
result = df.query('trx_category == "C2C_IN" or trx_category == "C2C_OUT"').groupby(['cl_id'])['amount'].sum().sort_values(ascending=False).reset_index()
result.head(5)
# Out:
#    cl_id     amount
# 0   4445  3.237e+06
# 1   1408  1.896e+06
# 2   4211  1.714e+06
# 3   5373  1.262e+06
# 4   4340  1.259e+06

# %% [markdown]
# -------------------------------------------
#
# #### __8__. (2 points)
#
# __8.1.__ Прологарифмируйте сумму трат `amount`, а результат сохраните в столбец `amount_log`. Как нужно логарифмировать, чтобы не было проблем при `amount == 0`?
#
# Вместо $log(x)$ используем $log(1 + x)$

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################
df['amount_log'] = np.log1p(df['amount'])

# %% [markdown]
# __8.2__. Выполните onehot-кодирование для столбцов `channel_type` и `trx_category`. Полученные столбцы присоедините к таблице `df`, результат сохраните в переменную `df`.

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

df = pd.get_dummies(df, columns=['channel_type', 'trx_category'], prefix=['channel', 'trx'])

# %%
df.iloc[index].head()
# Out:
#             PERIOD  cl_id   MCC  currency TRDATETIME  amount  target_flag  \
# 51305   01/06/2017    913  7230       810 2017-06-14  2100.0            1
# 226863  01/07/2017   4183  5499       810 2017-07-20   140.0            1
# 124479  01/11/2017   2253  5735       810 2017-11-28   397.0            1
# 11132   01/08/2017    225  5411       810 2017-08-07    44.9            1
# 473017  01/03/2017   9869  5812       810 2017-03-30   350.0            0
#
#         target_sum  trx_category_mul  mday  ymonth  year  wday  is_weekend  \
# 51305    449004.29                -1    14       6  2017     2       False
# 226863   132726.55                -1    20       7  2017     3       False
# 124479       59.00                -1    28      11  2017     1       False
# 11132    466235.45                -1     7       8  2017     0       False
# 473017        0.00                -1    30       3  2017     3       False
#
#         mcc_group  amount_log  channel_type1  channel_type2  channel_type3  \
# 51305         7.0       7.650          False           True          False
# 226863       17.0       4.949           True          False          False
# 124479       15.0       5.986          False           True          False
# 11132        17.0       3.826          False          False          False
# 473017       15.0       5.861           True          False          False
#
#         channel_type4  channel_type5  trx_BACK_TRX  trx_C2C_IN  trx_C2C_OUT  \
# 51305           False          False         False       False        False
# 226863          False          False         False       False        False
# 124479          False          False         False       False        False
# 11132            True          False         False       False        False
# 473017          False          False         False       False        False
#
#         trx_CASH_ADV  trx_CAT  trx_DEPOSIT  trx_POS  trx_WD_ATM_OTHER  \
# 51305          False    False        False     True             False
# 226863         False    False        False     True             False
# 124479         False    False        False     True             False
# 11132          False    False        False     True             False
# 473017         False    False        False     True             False
#
#         trx_WD_ATM_PARTNER  trx_WD_ATM_ROS
# 51305                False           False
# 226863               False           False
# 124479               False           False
# 11132                False           False
# 473017               False           False

# %% [markdown]
# -----------------------------------------
#
# #### __9__. (2 points за правильную итоговую подтаблицу)
#
# Сохраните итоговую подтаблицу в файл.

# %%
df.iloc[index].to_csv('answer.csv', index=False, sep=',')

# %% [markdown]
# -----------------------------------------
#
# ## Бонусная часть (+3 балла)
#
# Попробуйте придумать решающее правило (без использования алгоритмов машинного обучения), по которому можно было бы предсказать значение переменной `target_flag`. **Запрещается** использовать переменную `target_sum`.
#
# Разобъем выборку на тренировочную и отложенную.

# %%
from sklearn.model_selection import train_test_split

mask = df.columns.str.startswith('target_')

target_cols  = df.columns[mask]
feature_cols = df.columns[~mask]

X, y = df.loc[:, feature_cols], df.loc[:, target_cols]

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.3, shuffle=True, random_state=9872)

# %% [markdown]
# Ваше решение должно побить следующий бейзлайн:
#
# ```python
# from sklearn.metrics import accuracy_score
#
# assert accuracy_score(y_test['target_flag'], y_pred) > 0.7
# ```
#
# **Запрещается** использовать отложенную выборку `(X_test, y_test)` для выбора решения.
#
# **Вопрос:** Что показывает метрика `accuracy`?
#
# $\textcolor{red}{Ваш \ ответ:}$

# %% [markdown]
# ### Вопросы и подсказки
#
# Исследуйте рапределения и зависимости между признаками отностительно целевой переменной `target_flag`. Для решения этой задачи вам может быть полезна визуализация.
#
# 1. Какие любопытные выводы можно сделать из такого анализа?
# 2. Какие проблемы возникают с визуализацией совместного распредления категориальных (дискретных) и непрерывных значений? Как эту проблему можно решить?
# 3. В исходном датасете очень много записей, поэтому визуализация может работать **неприемлемо** долго. Как решить эту проблему?
#
# Приведите ниже код и комментарии с ответами на вопросы выше.

# %% [markdown]
# __Ответы на вопросы:__
#
# **1.** _put your answers here_
#
# **2.**  _put your answers here_
#
# **3.** _put your answers here_

# %%
# put your code here

# %% [markdown]
# ### Решение

# %%
#############################
### ╰( ͡° ͜ʖ ͡° )つ──────☆*:・ﾟ
#############################

# %%
accuracy_score(y_test['target_flag'], y_pred)
# Out:
# 0.7309009608981067
